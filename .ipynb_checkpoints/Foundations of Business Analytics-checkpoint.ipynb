# %% [markdown]
# # Book list in reading order
# - explorarory data analysis (/Users/meiyaoli/Documents/ebook/Think_Stats_EXPLORATORY_DATA_ANALYSIS.pdf)

# %% [markdown]
# # EDA

# %% [markdown]
# ## Steps of data exploration and preparation
# 1. varialbe identification
#     - types of variables (predictor/target; varialbe categories continuous/categorical; data types caractor/numeric;)
#     - data source & collection process
# 2. univiriate analysis
#     - distribution
#     - outliers
#         - categorical use count/count%;
#         - continuous use central tendency and spread (visualization: boxplot histogram)
# 3. bi-variate analysis
#     - correlation:
#        - categorical: 2-way table; stacked column chart; chi-square test
#        - categorical & continuous: Z/T test; ANOVA
# 4. missing values
# 5. outliers
# 6. variable transformation
# 7. variable creation

# %% [markdown]
# ## EDA key concepts
# - exploratory
#     - central tendency
#     - spread
#     - distribution
#     - trend
#     - outliers
#     - correlations
# - confirmatory
#     - hypothesis testing

# %% [markdown]
# # CRISP-DM
# cross industry standard process for data mining
#
# - business understanding
# - data understanding
# - data preparation
# - modeling
# - evaluation
# - deployment

# %% [markdown]
# # analytic project life cycle
# ![Screenshot%202023-09-05%20at%2010.35.31%20AM.png](attachment:Screenshot%202023-09-05%20at%2010.35.31%20AM.png)

# %% [markdown]
# # EDA related

# %% [markdown]
# ## data visualization for data exploration
#
# - use of visualization
#     - observe general behavior of data
#     - draw tentative hypothesis regarding data

# %% [markdown]
# ## data types
# ![data%20types.png](attachment:data%20types.png)

# %% [markdown]
# ## data summarization
# - central tendency
#     - mean
#     - median
#     - mode
# - variability/spread
#     - range
#     - variance
#     - standard deviation

# %% [markdown]
# ![mean%20median%20mode.png](attachment:mean%20median%20mode.png)

# %% [markdown]
# ![variability.png](attachment:variability.png)

# %% [markdown]
# ![Variance-and-Standard-Deviation.png](attachment:Variance-and-Standard-Deviation.png)

# %% [markdown]
# Coefficient of Variation
#
# - The co-efficient of variation is a simple way to compare the degree of variation from one data series to another.
# - A serious disadvantage of the standard deviation as a measure of variation is that it depends on the units of measurement. Coefficient of variation provides measure of relative variation, which epresses the standard deviation as a percentage of what is being measured
#
# ![Coefficient%20of%20Variation.png](attachment:Coefficient%20of%20Variation.png)

# %% [markdown]
# standard error of the mean
#
# SEM = S/√n
#
# - Standard deviation (SD) measures the dispersion of a dataset relative to its mean.
# - SD is used frequently in statistics, and in finance is often used as a proxy for the volatility or riskiness of an investment.
# - The standard error of the mean (SEM) measures how much discrepancy is likely in a sample’s mean compared with the population mean.
# - The SEM takes the SD and divides it by the square root of the sample size.
# - The SEM will always be smaller than the SD.

# %% [markdown]
# ## EDA using graphs
# - histogram - numeric data
#     - bin size important
# - bar char - categorical data
# - scatter plot
#     - detect outliers
#     - spot trend lines
# - box plot
# - correlation matrix
# - **QQ plot**

# %% [markdown]
# # continuous probability distribution, estimation, hypothesis testing & ANOVA

# %% [markdown]
# ## Anova
# To compare different groups of data and determine if they are
# - identical or different
# - how significant is the difference
